# %%
import pandas as pd


def create_email_agg_df(df):

    # Read the data from a CSV file
    df = pd.read_csv('./outputs/email_metadata.csv')

    # Convert 'date_sent' to datetime format
    df['date_sent'] = pd.to_datetime(df['date_sent'])

    # Sort the DataFrame by sender_email and date_sent
    df = df.sort_values(['sender_email', 'date_sent'], ascending=[True, False])

    # Calculate the time difference between consecutive emails for the same sender
    df['time_diff'] = df.groupby('sender_email')['date_sent'].diff()

    # Convert time difference to a more readable format (like days)
    df['time_diff_days'] = df['time_diff'].dt.days

    # Create a DataFrame for email count per sender
    count_df = df.groupby('sender_email', as_index=False)['date_sent'].count()
    count_df.rename(columns={'date_sent': 'email_count'}, inplace=True)

    # Drop rows where 'time_diff' is NaT or NaN
    filtered_df = df.dropna(subset=['time_diff'])

    # Group by sender_email and calculate the average time difference in days
    agg_df = filtered_df.groupby('sender_email', as_index=False).agg({
        'time_diff_days': 'mean'  # mean time difference
    })

    # Rename columns for clarity
    agg_df.rename(columns={'time_diff_days': 'average_time_diff_days'}, inplace=True)

    # Merge the aggregated DataFrame with the count DataFrame
    final_df = pd.merge(agg_df, count_df, on='sender_email')
    final_df = final_df.sort_values(by = ['email_count'], ascending=False)

    # Display the final DataFrame
    return final_df



def get_latest_email_id(df, sender_email):
    # First, filter the DataFrame to only include rows where sender_email matches the input
    filtered_df = df[df['sender_email'] == sender_email]
    
    # If no records are found, return a message
    if filtered_df.empty:
        return "No emails found from this sender."
    
    # Then, sort the DataFrame by 'date_sent' in descending order
    sorted_df = filtered_df.sort_values('date_sent', ascending=False)
    
    # Get the 'email_id' of the first row, which will be the latest email
    latest_email_id = sorted_df.iloc[0]['email_id']
    
    return latest_email_id
# Out:
#                                          sender_email  average_time_diff_days
# 27                              noreply@glassdoor.com               -1.222222  \
# 11                                  hello@readwise.io               -1.333333
# 10                           hello@projectratchet.com               -1.200000
# 44      update-948635-2551e525@news.theregister.co.uk               -2.000000
# 20                            news@email-blacks.co.uk               -1.666667
# 39                               support@organifi.com               -2.500000
# 1                              activity@classlist.com               -2.000000
# 16                           marketing@clearscore.com               -2.000000
# 0                          SC9192096a@schoolcomms.com               -1.500000
# 3                                bonjour@e.cote.co.uk               -2.000000
# 5                              dan@tldrnewsletter.com               -2.000000
# 7                            gousto@info.gousto.co.uk               -2.500000
# 2                          amazon-offers@amazon.co.uk               -2.000000
# 30                          premium@academia-mail.com               -2.000000
# 31                  puregym@offers.emails-puregym.com               -1.000000
# 32                               samydoreau@gmail.com               -1.000000
# 33                               service@paypal.co.uk               -1.000000
# 34                     shipment-tracking@amazon.co.uk               -1.000000
# 35                       stories-features@mail.ft.com               -4.000000
# 37                           support@digitalocean.com               -1.000000
# 36                                 support@codepen.io               -1.000000
# 28                              noreply@gorillasun.de               -2.000000
# 38                             support@mantasleep.com               -5.000000
# 40                                     team@healf.com               -3.000000
# 41  team_at_trydirection_com_9fzkwg4x6d_af961a66@p...               -3.000000
# 42              theintelligentworker@mail.beehiiv.com               -3.000000
# 43                                      uber@uber.com               -2.000000
# 29                          noreply@miniathletics.com               -2.000000
# 9                                      hello@every.to               -3.000000
# 8                               hello@dirteaworld.com               -1.000000
# 26                            noreply@e.economist.com               -3.000000
# 25                            noreply-uk@klarna.co.uk               -3.000000
# 24                           no_reply@email.apple.com               -1.000000
# 23                            no-reply@primevideo.com               -1.000000
# 4                               contact@oakywood.shop               -4.000000
# 21                      no-reply@classroom.google.com               -2.000000
# 19             microsoftstore@microsoftstoreemail.com               -1.000000
# 18              messaging-digest-noreply@linkedin.com               -1.000000
# 17                      messages-noreply@linkedin.com               -1.000000
# 6                                   enews@coravin.com               -1.000000
# 15                                  info@onewheel.com               -1.000000
# 14                           info@mp1.tripadvisor.com               -1.000000
# 13  hello_at_mail_blinkist_com_b65by69kdd_6f8945da...               -2.000000
# 12                                hello@tryhackme.com               -1.000000
# 22                         no-reply@mail.coinbase.com               -2.000000
#
#     email_count
# 27           10
# 11            7
# 10            6
# 44            4
# 20            4
# 39            3
# 1             3
# 16            3
# 0             3
# 3             3
# 5             3
# 7             3
# 2             3
# 30            2
# 31            2
# 32            2
# 33            2
# 34            2
# 35            2
# 37            2
# 36            2
# 28            2
# 38            2
# 40            2
# 41            2
# 42            2
# 43            2
# 29            2
# 9             2
# 8             2
# 26            2
# 25            2
# 24            2
# 23            2
# 4             2
# 21            2
# 19            2
# 18            2
# 17            2
# 6             2
# 15            2
# 14            2
# 13            2
# 12            2
# 22            2
